# %%
import os

# %%
exp_dir = '../experiments'
print os.listdir(experiment_dir)
experiments = [ d for d in os.listdir(experiment_dir) if os.path.isdir(os.path.join(exp_dir,d)) ]
print experiments
# Out:
# ['tagger_experiments.csv', 'tagger_Feb-02-2017-17:27:643673', 'tagger_Feb-02-2017-18:39:661419', 'tagger_Feb-02-2017-18:40:076768', 'tagger_Feb-02-2017-19:02:898331', 'tagger_Feb-02-2017-19:19:256420']
# ['tagger_Feb-02-2017-17:27:643673', 'tagger_Feb-02-2017-18:39:661419', 'tagger_Feb-02-2017-18:40:076768', 'tagger_Feb-02-2017-19:02:898331', 'tagger_Feb-02-2017-19:19:256420']

# %%
for d in os.walk(experiment_dir):
    print d
# Out:
# ('../experiments', ['tagger_Feb-02-2017-17:27:643673', 'tagger_Feb-02-2017-18:39:661419', 'tagger_Feb-02-2017-18:40:076768', 'tagger_Feb-02-2017-19:02:898331', 'tagger_Feb-02-2017-19:19:256420'], ['tagger_experiments.csv'])
# ('../experiments/tagger_Feb-02-2017-17:27:643673', ['docs'], ['config.yaml', 'eval_stats.json', 'tagger.model', 'train_stats.json'])
# ...
